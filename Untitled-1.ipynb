# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.naive_bayes import MultinomialNB, GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    ConfusionMatrixDisplay
)
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_validate
from imblearn.over_sampling import SMOTE
import numpy as np
from sklearn.impute import KNNImputer
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

# %%
df = pd.read_csv("retail_store_sales.csv") # loading dataset

# %%
df.head() # initial data check``
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
#
#    Quantity  Total Spent  Payment Method Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet   Online       2024-04-08
# 1       9.0        261.0  Digital Wallet   Online       2023-07-23
# 2       2.0         43.0     Credit Card   Online       2022-10-05
# 3       9.0        247.5     Credit Card   Online       2022-05-07
# 4       7.0         87.5  Digital Wallet   Online       2022-10-02
#
#   Discount Applied
# 0             True
# 1             True
# 2            False
# 3              NaN
# 4            False

# %%
df.describe() # statistical summary
# Out:
#        Price Per Unit      Quantity   Total Spent
# count    11966.000000  11971.000000  11971.000000
# mean        23.365912      5.536380    129.652577
# std         10.743519      2.857883     94.750697
# min          5.000000      1.000000      5.000000
# 25%         14.000000      3.000000     51.000000
# 50%         23.000000      6.000000    108.500000
# 75%         33.500000      8.000000    192.000000
# max         41.000000     10.000000    410.000000

# %%
df.info() # check for data types and null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12575 entries, 0 to 12574
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    12575 non-null  object
#  1   Customer ID       12575 non-null  object
#  2   Category          12575 non-null  object
#  3   Item              11362 non-null  object
#  4   Price Per Unit    11966 non-null  float64
#  5   Quantity          11971 non-null  float64
#  6   Total Spent       11971 non-null  float64
#  7   Payment Method    12575 non-null  object
#  8   Location          12575 non-null  object
#  9   Transaction Date  12575 non-null  object
#  10  Discount Applied  8376 non-null   object
# dtypes: float64(3), object(8)
# memory usage: 1.1+ MB

# %% [markdown]
# DATA CLEANING

# %%
df = df.drop(columns = ["Customer ID","Transaction ID","Total Spent"]) # dropping irrelevant columns

# %%
df.drop_duplicates(inplace=True) # removing duplicates
df.duplicated().sum() # check for duplicates = 0
# Out:
# np.int64(0)

# %%
df['Price Per Unit'].fillna(df['Price Per Unit'].median(), inplace=True) # filling missing values with median
df['Quantity'].fillna(df['Quantity'].median(), inplace=True) # filling missing values with median

df.info() # check for data types and null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12571 entries, 0 to 12574
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Category          12571 non-null  object
#  1   Item              11358 non-null  object
#  2   Price Per Unit    12571 non-null  float64
#  3   Quantity          12571 non-null  float64
#  4   Payment Method    12571 non-null  object
#  5   Location          12571 non-null  object
#  6   Transaction Date  12571 non-null  object
#  7   Discount Applied  8375 non-null   object
# dtypes: float64(2), object(6)
# memory usage: 883.9+ KB
# C:\Users\mosta\AppData\Local\Temp\ipykernel_12496\3145926016.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Price Per Unit'].fillna(df['Price Per Unit'].median(), inplace=True) # filling missing values with median
# C:\Users\mosta\AppData\Local\Temp\ipykernel_12496\3145926016.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Quantity'].fillna(df['Quantity'].median(), inplace=True) # filling missing values with median

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12571 entries, 0 to 12574
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Category          12571 non-null  object
#  1   Item              11358 non-null  object
#  2   Price Per Unit    12571 non-null  float64
#  3   Quantity          12571 non-null  float64
#  4   Payment Method    12571 non-null  object
#  5   Location          12571 non-null  object
#  6   Transaction Date  12571 non-null  object
#  7   Discount Applied  8375 non-null   object
# dtypes: float64(2), object(6)
# memory usage: 883.9+ KB

# %% [markdown]
# FEATURE ENG

# %%
df['Transaction Date'] = pd.to_datetime(df['Transaction Date']) # converting to datetime
df['Month'] = df['Transaction Date'].dt.month # extracting month
df['Day'] = df['Transaction Date'].dt.day # extracting day
df['Year'] = df['Transaction Date'].dt.year # extracting year
df = df.drop(columns=['Transaction Date']) # dropping original date column
df['Total Spent'] = df['Price Per Unit'] * df['Quantity'] # creating total spent column
df.info() # check for data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12571 entries, 0 to 12574
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Category          12571 non-null  object
#  1   Item              11358 non-null  object
#  2   Price Per Unit    12571 non-null  float64
#  3   Quantity          12571 non-null  float64
#  4   Payment Method    12571 non-null  object
#  5   Location          12571 non-null  object
#  6   Discount Applied  8375 non-null   object
#  7   Month             12571 non-null  int32
#  8   Day               12571 non-null  int32
#  9   Year              12571 non-null  int32
#  10  Total Spent       12571 non-null  float64
# dtypes: float64(3), int32(3), object(5)
# memory usage: 1.0+ MB

# %% [markdown]
# EDA AND DATA VISUALISATION

# %%
plt.pie(df["Category"].value_counts(), labels=df["Category"].value_counts().index, autopct='%1.1f%%') 
plt.title("Distribution of Item Categories") # pie chart of item categories
plt.show()

# %%
plt.pie(df['Payment Method'].value_counts(), labels=df['Payment Method'].value_counts().index, autopct='%1.1f%%')
plt.title("Distribution of Payment Methods") # pie chart of payment methods
plt.show()

# %%
plt.pie(df["Location"].value_counts(), labels=df["Location"].value_counts().index, autopct='%1.1f%%')
plt.title("Distribution of Store Locations") # pie chart of store locations
plt.show()

# %%
plt.scatter(df['Quantity'], df['Price Per Unit'])

# %%
sns.boxplot(x='Month', y='Quantity', data=df) # box plot of total spent by month
plt.title('Sales Distribution by Month') 
plt.show()

# %%
sns.boxplot(x='Day', y='Quantity', data=df) # box plot of total spent by Day
plt.title('Sales Distribution by Month') 
plt.show()

# %%
sns.boxplot(x='Year', y='Quantity', data=df) # box plot of total spent by month
plt.title('Sales Distribution by Month') 
plt.show()

# %%
eda_df = df.drop(columns=["Item"])  # creating a copy without 'Item' column for EDA
num_cols = eda_df.select_dtypes(include=['int64', 'float64']).columns
cat_cols = eda_df.select_dtypes(include=['object', 'category']).columns

# %%
# Display basic info
print("Shape of dataset:", df.shape)
print("\nData types:\n", df.dtypes)
print("\nMissing values:\n", df.isnull().sum())
# -----------------------------
# Univariate Analysis: Numerical Variables
# -----------------------------
for col in num_cols:
    print(f"\n===== {col} =====")
    print(df[col].describe())
    
    plt.figure(figsize=(12,4))
    
    plt.subplot(1,2,1)
    sns.histplot(df[col], kde=True, color='skyblue')
    plt.title(f"Distribution of {col}")
    
    plt.subplot(1,2,2)
    sns.boxplot(x=df[col], color='lightgreen')
    plt.title(f"Boxplot of {col}")
    
    plt.show()

# -----------------------------
# Univariate Analysis: Categorical Variables
# -----------------------------
for col in cat_cols:
    print(f"\n===== {col} =====")
    print(df[col].value_counts(normalize=True).round(3) * 100)
    
    plt.figure(figsize=(8,4))
    sns.countplot(x=df[col], palette='pastel', order=df[col].value_counts().index)
    plt.title(f"Count Plot of {col}")
    plt.xticks(rotation=45)
    plt.show()
# Out:
# Shape of dataset: (12571, 11)
#
# Data types:
#  Category             object
# Item                 object
# Price Per Unit      float64
# Quantity            float64
# Payment Method       object
# Location             object
# Discount Applied     object
# Month                 int32
# Day                   int32
# Year                  int32
# Total Spent         float64
# dtype: object
#
# Missing values:
#  Category               0
# Item                1213
# Price Per Unit         0
# Quantity               0
# Payment Method         0
# Location               0
# Discount Applied    4196
# Month                  0
# Day                    0
# Year                   0
# Total Spent            0
# dtype: int64
#
# ===== Price Per Unit =====
# count    12571.000000
# mean        23.347586
# std         10.481094
# min          5.000000
# 25%         14.000000
# 50%         23.000000
# 75%         32.000000
# max         41.000000
# Name: Price Per Unit, dtype: float64
# ===== Quantity =====
# count    12571.000000
# mean         5.558746
# std          2.790274
# min          1.000000
# 25%          3.000000
# 50%          6.000000
# 75%          8.000000
# max         10.000000
# Name: Quantity, dtype: float64
# ===== Total Spent =====
# count    12571.000000
# mean       130.117214
# std         92.338026
# min          5.000000
# 25%         55.000000
# 50%        111.000000
# 75%        192.000000
# max        410.000000
# Name: Total Spent, dtype: float64
# ===== Category =====
# Category
# Electric household essentials         12.6
# Furniture                             12.6
# Food                                  12.6
# Milk Products                         12.6
# Butchers                              12.5
# Beverages                             12.5
# Computers and electric accessories    12.4
# Patisserie                            12.2
# Name: proportion, dtype: float64
# C:\Users\mosta\AppData\Local\Temp\ipykernel_12496\597306658.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[col], palette='pastel', order=df[col].value_counts().index)
# ===== Payment Method =====
# Payment Method
# Cash              34.3
# Digital Wallet    32.9
# Credit Card       32.8
# Name: proportion, dtype: float64
# C:\Users\mosta\AppData\Local\Temp\ipykernel_12496\597306658.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[col], palette='pastel', order=df[col].value_counts().index)
# ===== Location =====
# Location
# Online      50.5
# In-store    49.5
# Name: proportion, dtype: float64
# C:\Users\mosta\AppData\Local\Temp\ipykernel_12496\597306658.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[col], palette='pastel', order=df[col].value_counts().index)
# ===== Discount Applied =====
# Discount Applied
# True     50.4
# False    49.6
# Name: proportion, dtype: float64
# C:\Users\mosta\AppData\Local\Temp\ipykernel_12496\597306658.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[col], palette='pastel', order=df[col].value_counts().index)

# %%
# ==============================
# 1️⃣ NUMERICAL vs NUMERICAL
# ==============================
print("\n=== Numerical vs Numerical Relationships ===")

for i, col1 in enumerate(num_cols):
    for j, col2 in enumerate(num_cols):
        if i < j:
            print(f"\nRelationship: {col1} vs {col2}")
            print("Correlation:", round(df[col1].corr(df[col2]), 3))

            plt.figure(figsize=(6,4))
            sns.scatterplot(x=df[col1], y=df[col2], alpha=0.6, color='teal')
            plt.title(f"{col1} vs {col2}")
            plt.show()

# Optional: Heatmap for overall correlation
plt.figure(figsize=(10,6))
sns.heatmap(df[num_cols].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap (Numerical Variables)")
plt.show()


# ==============================
# 2️⃣ CATEGORICAL vs NUMERICAL
# ==============================
print("\n=== Categorical vs Numerical Relationships ===")

for cat in cat_cols:
    for num in num_cols:
        plt.figure(figsize=(8,5))
        sns.boxplot(x=df[cat], y=df[num], palette='pastel')
        plt.title(f"{num} across {cat}")
        plt.xticks(rotation=45)
        plt.show()


# ==============================
# 3️⃣ CATEGORICAL vs CATEGORICAL
# ==============================
print("\n=== Categorical vs Categorical Relationships ===")

for i, col1 in enumerate(cat_cols):
    for j, col2 in enumerate(cat_cols):
        if i < j:
            print(f"\n{col1} vs {col2}")
            cross_tab = pd.crosstab(df[col1], df[col2], normalize='index') * 100
            print(cross_tab.round(2))
            
            plt.figure(figsize=(8,5))
            sns.heatmap(cross_tab, annot=True, cmap='YlGnBu', fmt=".1f")
            plt.title(f"{col1} vs {col2}")
            plt.show()
# Out:
# === Numerical vs Numerical Relationships ===
#
# Relationship: Price Per Unit vs Quantity
# Correlation: 0.011
# Relationship: Price Per Unit vs Total Spent
# Correlation: 0.634
# Relationship: Quantity vs Total Spent
# Correlation: 0.713
# === Categorical vs Numerical Relationships ===
# C:\Users\mosta\AppData\Local\Temp\ipykernel_12496\3196922139.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df[cat], y=df[num], palette='pastel')
# C:\Users\mosta\AppData\Local\Temp\ipykernel_12496\3196922139.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df[cat], y=df[num], palette='pastel')
# C:\Users\mosta\AppData\Local\Temp\ipykernel_12496\3196922139.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df[cat], y=df[num], palette='pastel')
# C:\Users\mosta\AppData\Local\Temp\ipykernel_12496\3196922139.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df[cat], y=df[num], palette='pastel')
# C:\Users\mosta\AppData\Local\Temp\ipykernel_12496\3196922139.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df[cat], y=df[num], palette='pastel')
# C:\Users\mosta\AppData\Local\Temp\ipykernel_12496\3196922139.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df[cat], y=df[num], palette='pastel')
# C:\Users\mosta\AppData\Local\Temp\ipykernel_12496\3196922139.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df[cat], y=df[num], palette='pastel')
# C:\Users\mosta\AppData\Local\Temp\ipykernel_12496\3196922139.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df[cat], y=df[num], palette='pastel')
# C:\Users\mosta\AppData\Local\Temp\ipykernel_12496\3196922139.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df[cat], y=df[num], palette='pastel')
# C:\Users\mosta\AppData\Local\Temp\ipykernel_12496\3196922139.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df[cat], y=df[num], palette='pastel')
# C:\Users\mosta\AppData\Local\Temp\ipykernel_12496\3196922139.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df[cat], y=df[num], palette='pastel')
# C:\Users\mosta\AppData\Local\Temp\ipykernel_12496\3196922139.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df[cat], y=df[num], palette='pastel')
# === Categorical vs Categorical Relationships ===
#
# Category vs Payment Method
# Payment Method                       Cash  Credit Card  Digital Wallet
# Category
# Beverages                           36.97        30.59           32.44
# Butchers                            33.16        35.27           31.57
# Computers and electric accessories  35.11        33.31           31.58
# Electric household essentials       33.84        30.63           35.53
# Food                                35.29        31.88           32.83
# Furniture                           33.14        33.33           33.52
# Milk Products                       33.27        34.15           32.58
# Patisserie                          33.38        33.12           33.51
# Category vs Location
# Location                            In-store  Online
# Category
# Beverages                              49.81   50.19
# Butchers                               50.00   50.00
# Computers and electric accessories     46.53   53.47
# Electric household essentials          48.55   51.45
# Food                                   49.97   50.03
# Furniture                              50.75   49.25
# Milk Products                          49.94   50.06
# Patisserie                             50.20   49.80
# Category vs Discount Applied
# Discount Applied                    False  True
# Category
# Beverages                           48.67  51.33
# Butchers                            48.63  51.37
# Computers and electric accessories  50.51  49.49
# Electric household essentials       50.29  49.71
# Food                                51.85  48.15
# Furniture                           47.60  52.40
# Milk Products                       50.41  49.59
# Patisserie                          48.86  51.14
# Payment Method vs Location
# Location        In-store  Online
# Payment Method
# Cash               49.63   50.37
# Credit Card        49.02   50.98
# Digital Wallet     49.76   50.24
# Payment Method vs Discount Applied
# Discount Applied  False  True
# Payment Method
# Cash              48.55  51.45
# Credit Card       49.31  50.69
# Digital Wallet    51.02  48.98
# Location vs Discount Applied
# Discount Applied  False  True
# Location
# In-store          49.82  50.18
# Online            49.44  50.56

# %%
# ==============================
# 1️⃣ Pairplot for all numerical variables
# ==============================
sns.pairplot(df[num_cols], diag_kind='kde')
plt.suptitle("Pairwise Relationships Between Numerical Variables", y=1.02)
plt.show()


# ==============================
# 2️⃣ Correlation Heatmap
# ==============================
plt.figure(figsize=(10,6))
sns.heatmap(df[num_cols].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()


# ==============================
# 3️⃣ Multivariate Relationship: 2 numeric + 1 categorical
# Example: Income vs Age colored by Gender
# ==============================
if len(cat_cols) > 0 and len(num_cols) > 1:
    sns.scatterplot(
        data=df,
        x=num_cols[0],
        y=num_cols[1],
        hue=cat_cols[0],    # color points by category
        style=cat_cols[0],  # optional: different marker shapes
        alpha=0.7
    )
    plt.title(f"{num_cols[0]} vs {num_cols[1]} colored by {cat_cols[0]}")
    plt.show()


# ==============================
# 4️⃣ Multivariate Relationship: 2 numeric + 1 categorical (Boxplot)
# ==============================
if len(cat_cols) > 0 and len(num_cols) > 0:
    sns.boxplot(
        data=df,
        x=cat_cols[0],
        y=num_cols[0],
        hue=cat_cols[1] if len(cat_cols) > 1 else None,
        palette="Set2"
    )
    plt.title(f"{num_cols[0]} distribution across {cat_cols[0]}")
    plt.xticks(rotation=45)
    plt.show()


# ==============================
# 5️⃣ Pairwise relationships with category hue
# (Like pairplot, but colored by a categorical variable)
# ==============================
if len(cat_cols) > 0:
    sns.pairplot(df, hue=cat_cols[0], diag_kind="kde", palette="husl")
    plt.suptitle(f"Pairplot with {cat_cols[0]} as hue", y=1.02)
    plt.show()

# %% [markdown]
# MISSING DATA

# %%
df.loc[df["Discount Applied"].isnull(), "Discount Applied"] = np.nan

# %% [markdown]
# DATA ENCODING

# %%
cols = ["Item","Payment Method", "Location", 'Discount Applied']
df= pd.get_dummies(df, columns=cols)

# %% [markdown]
# OUTLIERS

# %%
cols = ['Quantity', 'Price Per Unit']

lower_limit = df[cols].quantile(0.05)
upper_limit = df[cols].quantile(0.95)

df[cols] = df[cols].clip(lower=lower_limit, upper=upper_limit, axis=1)

# %%
df.head()
# Out:
#         Category  Price Per Unit  Quantity  Month  Day  Year  Total Spent  \
# 0     Patisserie            18.5      10.0      4    8  2024        185.0
# 1  Milk Products            29.0       9.0      7   23  2023        261.0
# 2       Butchers            21.5       2.0     10    5  2022         43.0
# 3      Beverages            27.5       9.0      5    7  2022        247.5
# 4           Food            12.5       7.0     10    2  2022         87.5
#
#    Item_Item_10_BEV  Item_Item_10_BUT  Item_Item_10_CEA  ...  Item_Item_9_FUR  \
# 0             False             False             False  ...            False
# 1             False             False             False  ...            False
# 2             False             False             False  ...            False
# 3             False             False             False  ...            False
# 4             False             False             False  ...            False
#
#    Item_Item_9_MILK  Item_Item_9_PAT  Payment Method_Cash  \
# 0             False            False                False
# 1             False            False                False
# 2             False            False                False
# 3             False            False                False
# 4             False            False                False
#
#    Payment Method_Credit Card  Payment Method_Digital Wallet  \
# 0                       False                           True
# 1                       False                           True
# 2                        True                          False
# 3                        True                          False
# 4                       False                           True
#
#    Location_In-store  Location_Online  Discount Applied_False  \
# 0              False             True                   False
# 1              False             True                   False
# 2              False             True                    True
# 3              False             True                   False
# 4              False             True                    True
#
#    Discount Applied_True
# 0                   True
# 1                   True
# 2                  False
# 3                  False
# 4                  False
#
# [5 rows x 214 columns]

# %%
le = LabelEncoder()
df["Category"] = le.fit_transform(df["Category"])
x = df.drop(columns=['Category'])
y = (df['Category'])
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)  # splitting data

# %%
models = []
models.append(('LR', LogisticRegression()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('DECT', DecisionTreeClassifier()))
models.append(('RC', RandomForestClassifier()))
models.append(('GUSS', GaussianNB()))  
models.append(('XG', XGBClassifier(use_label_encoder=False, eval_metric='logloss')))  
models.append(('SVM', SVC()))

# %%
for model in models:
    steps = [
        ('Scaler', MinMaxScaler()),
        ('Classifier', model[1])
    ]
    pipeline = Pipeline(steps=steps)
    
    scores = cross_validate(
        pipeline, x, y, cv=5,
        scoring=['accuracy', 'precision_weighted', 'recall_weighted', 'f1_weighted'],
        return_train_score=True
    )
    
    print(f"Model: {model[0]}")
    print("Train Accuracy : ", scores["train_accuracy"].mean())
    print("Test Accuracy  : ", scores["test_accuracy"].mean())
    print("Train Precision: ", scores["train_precision_weighted"].mean())
    print("Test Precision : ", scores["test_precision_weighted"].mean())
    print("Train Recall   : ", scores["train_recall_weighted"].mean())
    print("Test Recall    : ", scores["test_recall_weighted"].mean())
    print("Train F1 Score : ", scores["train_f1_weighted"].mean())
    print("Test F1 Score  : ", scores["test_f1_weighted"].mean())
    print('-' * 60)
# Out:
# Model: LR
# Train Accuracy :  0.9198154410077356
# Test Accuracy  :  0.9152013614415336
# Train Precision:  0.922038254587199
# Test Precision :  0.9177569419329201
# Train Recall   :  0.9198154410077356
# Test Recall    :  0.9152013614415336
# Train F1 Score :  0.9203070983818389
# Test F1 Score  :  0.9157345342511579
# ------------------------------------------------------------
# Model: KNN
# Train Accuracy :  0.8791265383970082
# Test Accuracy  :  0.7526843711003668
# Train Precision:  0.883131999680381
# Test Precision :  0.7635123537335757
# Train Recall   :  0.8791265383970082
# Test Recall    :  0.7526843711003668
# Train F1 Score :  0.8795193039477969
# Test F1 Score  :  0.7538938840859125
# ------------------------------------------------------------
# Model: DECT
# Train Accuracy :  1.0
# Test Accuracy  :  0.9155197059488731
# Train Precision:  1.0
# Test Precision :  0.9157980110855284
# Train Recall   :  1.0
# Test Recall    :  0.9155197059488731
# Train F1 Score :  1.0
# Test F1 Score  :  0.9155375516041004
# ------------------------------------------------------------
# Model: RC
# Train Accuracy :  1.0
# Test Accuracy  :  0.9155991339156785
# Train Precision:  1.0
# Test Precision :  0.9159983714100874
# Train Recall   :  1.0
# Test Recall    :  0.9155991339156785
# Train F1 Score :  1.0
# Test F1 Score  :  0.9156609341805492
# ------------------------------------------------------------
# Model: GUSS
# Train Accuracy :  0.9161959883556332
# Test Accuracy  :  0.9162355066102984
# Train Precision:  0.949130288790432
# Test Precision :  0.9491514295406098
# Train Recall   :  0.9161959883556332
# Test Recall    :  0.9162355066102984
# Train F1 Score :  0.9243844217438222
# Test F1 Score  :  0.924371275008356
# ------------------------------------------------------------
# c:\Users\mosta\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\training.py:183: UserWarning: [18:01:01] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\mosta\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\training.py:183: UserWarning: [18:01:02] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\mosta\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\training.py:183: UserWarning: [18:01:03] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\mosta\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\training.py:183: UserWarning: [18:01:03] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\mosta\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\training.py:183: UserWarning: [18:01:04] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Model: XG
# Train Accuracy :  0.9536234216754476
# Test Accuracy  :  0.9155195794208495
# Train Precision:  0.9543406133414083
# Test Precision :  0.9169653030049403
# Train Recall   :  0.9536234216754476
# Test Recall    :  0.9155195794208495
# Train F1 Score :  0.9537464517028014
# Test F1 Score  :  0.9158150603701583
# ------------------------------------------------------------
# Model: SVM
# Train Accuracy :  0.9223808440655171
# Test Accuracy  :  0.9148832383582356
# Train Precision:  0.9385034755727455
# Test Precision :  0.9329730986832327
# Train Recall   :  0.9223808440655171
# Test Recall    :  0.9148832383582356
# Train F1 Score :  0.9260266188254462
# Test F1 Score  :  0.9190507238461532
# ------------------------------------------------------------
